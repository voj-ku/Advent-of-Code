# %%
with open('../Data/Day 2/input.txt') as f:
    t = f.readlines()
cals = [i.replace('\n','') for i in t]

# %%
ord('A'), ord('B'), ord('C')
# Out:
# (65, 66, 67)

# %%
ord('X'),ord('Y'),ord('Z')
# Out:
# (88, 89, 90)

# %%
val1 = 'A'
val2 = 'X'

r1 = ord(val1) % 65
r2 = ord(val2) % 88

r1,r2
# Out:
# (0, 0)

# %%
ord('X') % ord('B')
# Out:
# 22

# %%
89 - 65 = 24 = 6
90 - 66 = 24 = 6
88 - 67 = 21 = 6

88 - 66 = 23 = 3 
89 - 67 = 23 = 3
90 - 65 = 23 = 3

88 - 66 = 22 = 0
89 - 67 = 22 = 0
90 - 65 = 25 = 0

# %%
def eval(comb):
    r1, r2 = ord(comb[0]), (ord(comb[2]) - 23)
    return r2-r1

# %%
for cal in cals:
    print(cal), print(eval(cal))
# Out:
# A Z
# 2
# A Y
# 1
# B X
# -1
# B X
# -1
# C X
# -2
# B X
# -1
# A X
# 0
# A X
# 0
# C X
# -2
# A X
# 0
# A X
# 0
# A Y
# 1
# B X
# -1
# A Y
# 1
# C X
# -2
# C X
# -2
# A X
# 0
# A Y
# 1
# C X
# -2
# B X
# -1
# A X
# 0
# B X
# -1
# A X
# 0
# A X
# 0
# B Y
# 0
# B Y
# 0
# A X
# 0
# A X
# 0
# A X
# 0
# A X
# 0
# A X
# 0
# A Y
# 1
# A X
# 0
# B X
# -1
# B Y
# 0
# A Y
# 1
# C Z
# 0
# C X
# -2
# A X
# 0
# A Y
# 1
# A X
# 0
# A X
# 0
# A Y
# 1
# A X
# 0
# A Y
# 1
# A X
# 0
# B X
# -1
# C X
# -2
# A X
# 0
# B X
# -1
# A X
# 0
# C X
# -2
# A Y
# 1
# B X
# -1
# B X
# -1
# A X
# 0
# A X
# 0
# C Y
# -1
# B X
# -1
# A X
# 0
# C X
# -2
# B X
# -1
# B X
# -1
# A X
# 0
# A X
# 0
# B X
# -1
# A Y
# 1
# C X
# -2
# A Y
# 1
# A X
# 0
# A X
# 0
# A Y
# 1
# B X
# -1
# A X
# 0
# A X
# 0
# A X
# 0
# B Y
# 0
# A X
# 0
# A X
# 0
# A Y
# 1
# A X
# 0
# A X
# 0
# B Y
# 0
# B Y
# 0
# B X
# -1
# C X
# -2
# B Y
# 0
# A X
# 0
# C X
# -2
# C X
# -2
# A Y
# 1
# A X
# 0
# A Z
# 2
# B X
# -1
# C X
# -2
# A Y
# 1
# B X
# ...

# %%
(ord('X') - 23) - ord('A')
# Out:
# 0

# %%
'B'>'A'
# Out:
# True

# %%
'A':'rock',
'B':'scissor',

# %%
shape_dict = {
    'X':1,
    'Y':2,
    'Z':3
}

outcome_dict = {
    'win':6,
    'draw':3,
    'lose':0
}

# %%
'A' & 'X' == 'draw'
'A' & 'Y' == ''

# %%
def result(a, b):

# %%
def eval(c:str):

    opp_choice, my_choice = c.split(' ')[0], c.split(' ')[1]

    if opp_choice

    shape_score = shape_dict(my_choice)

# %%
cals
# Out:
# ['A Z',
#  'A Y',
#  'B X',
#  'B X',
#  'C X',
#  'B X',
#  'A X',
#  'A X',
#  'C X',
#  'A X',
#  'A X',
#  'A Y',
#  'B X',
#  'A Y',
#  'C X',
#  'C X',
#  'A X',
#  'A Y',
#  'C X',
#  'B X',
#  'A X',
#  'B X',
#  'A X',
#  'A X',
#  'B Y',
#  'B Y',
#  'A X',
#  'A X',
#  'A X',
#  'A X',
#  'A X',
#  'A Y',
#  'A X',
#  'B X',
#  'B Y',
#  'A Y',
#  'C Z',
#  'C X',
#  'A X',
#  'A Y',
#  'A X',
#  'A X',
#  'A Y',
#  'A X',
#  'A Y',
#  'A X',
#  'B X',
#  'C X',
#  'A X',
#  'B X',
#  'A X',
#  'C X',
#  'A Y',
#  'B X',
#  'B X',
#  'A X',
#  'A X',
#  'C Y',
#  'B X',
#  'A X',
#  'C X',
#  'B X',
#  'B X',
#  'A X',
#  'A X',
#  'B X',
#  'A Y',
#  'C X',
#  'A Y',
#  'A X',
#  'A X',
#  'A Y',
#  'B X',
#  'A X',
#  'A X',
#  'A X',
#  'B Y',
#  'A X',
#  'A X',
#  'A Y',
#  'A X',
#  'A X',
#  'B Y',
#  'B Y',
#  'B X',
#  'C X',
#  'B Y',
#  'A X',
#  'C X',
#  'C X',
#  'A Y',
#  'A X',
#  'A Z',
#  'B X',
#  'C X',
#  'A Y',
#  'B X',
#  'A X',
#  'A X',
#  'A X',
# ...
